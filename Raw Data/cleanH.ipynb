# %%
import pandas as pd
import os

# %%
df=pd.read_csv('table-h-locally-owned-surplus-sites.csv')
df
# Out:
#      JURISDICTION     COUNTY  YEAR          APN  \
# 0       COACHELLA  RIVERSIDE  2020  767-731-018
# 1       COACHELLA  RIVERSIDE  2020  767-731-019
# 2       COACHELLA  RIVERSIDE  2020  767-731-020
# 3       COACHELLA  RIVERSIDE  2020  767-731-021
# 4       COACHELLA  RIVERSIDE  2020  767-731-022
# ...           ...        ...   ...          ...
# 2485      STANTON     ORANGE  2021   126-482-10
# 2486      STANTON     ORANGE  2021   126-482-09
# 2487      STANTON     ORANGE  2021   126-482-08
# 2488      STANTON     ORANGE  2021   126-482-06
# 2489      STANTON     ORANGE  2021   126-482-05
#
#                                          STREET_ADDRESS EXISTING_USE_TYPE  \
# 0     SE Corner of Ave 50 + Calhoun St., Coachella, ...            Vacant
# 1     SE Corner of Ave 50 + Calhoun St., Coachella, ...            Vacant
# 2     SE Corner of Ave 50 + Calhoun St., Coachella, ...            Vacant
# 3     SE Corner of Ave 50 + Calhoun St., Coachella, ...            Vacant
# 4     SE Corner of Ave 50 + Calhoun St., Coachella, ...            Vacant
# ...                                                 ...               ...
# 2485                                   8920 Pacific Ave       Residential
# 2486                                   8910 Pacific Ave       Residential
# 2487                                   8900 Pacific Ave       Residential
# 2488                                   8880 Pacific Ave       Residential
# 2489                                   8870 Pacific Ave       Residential
#
#       NUM_OF_UNITS  SURPLUS_TYPE  PARCEL_SIZE                       NOTES
# 0              0.0  Surplus Land        37.30  Part of 37.3 Acre Property
# 1              0.0  Surplus Land        37.30  Part of 37.3 Acre Property
# 2              0.0  Surplus Land        37.30  Part of 37.3 Acre Property
# 3              0.0  Surplus Land        37.30  Part of 37.3 Acre Property
# 4              0.0  Surplus Land        37.30  Part of 37.3 Acre Property
# ...            ...           ...          ...                         ...
# 2485           1.0  Surplus Land         0.17                Tina Pacific
# 2486           1.0  Surplus Land         0.17                Tina Pacific
# 2487           1.0  Surplus Land         0.17                Tina Pacific
# 2488           1.0  Surplus Land         0.17                Tina Pacific
# 2489           1.0  Surplus Land         0.17                Tina Pacific
#
# [2490 rows x 10 columns]

# %%
df['COUNTY'].unique()
# Out:
# array(['RIVERSIDE', 'MONTEREY', 'ALAMEDA', 'CONTRA COSTA', 'CALAVERAS',
#        'KINGS', 'LOS ANGELES', 'KERN', 'SAN DIEGO', 'STANISLAUS',
#        'ORANGE', 'SAN MATEO', 'SONOMA', 'SAN JOAQUIN', 'SANTA CLARA',
#        'SAN BERNARDINO', 'EL DORADO', 'TULARE', 'MARIN', 'FRESNO',
#        'VENTURA', 'MONO', 'SAN LUIS OBISPO', 'LAKE', 'SACRAMENTO',
#        'HUMBOLDT', 'PLACER', 'YOLO', 'SOLANO', 'SANTA CRUZ',
#        'SANTA BARBARA', 'BUTTE', 'SHASTA'], dtype=object)

# %%
df.drop(df[df['COUNTY'] != 'LOS ANGELES'].index, inplace=True)
df
# Out:
#      JURISDICTION       COUNTY  YEAR           APN  \
# 412   LOS ANGELES  LOS ANGELES  2021  5210-024-900
# 413   LOS ANGELES  LOS ANGELES  2021  2769-018-902
# 451       MAYWOOD  LOS ANGELES  2020  6313-001-901
# 452       MAYWOOD  LOS ANGELES  2020  6313-001-902
# 453       MAYWOOD  LOS ANGELES  2020  6314-024-900
# ...           ...          ...   ...           ...
# 2410        AZUSA  LOS ANGELES  2020  8611-004-914
# 2416        AZUSA  LOS ANGELES  2021  8611-004-914
# 2426      COMPTON  LOS ANGELES  2021  6145-003-902
# 2427      COMPTON  LOS ANGELES  2021  6166-022-901
# 2428      COMPTON  LOS ANGELES  2021  6184-002-902
#
#                                          STREET_ADDRESS EXISTING_USE_TYPE  \
# 412   Adjacent to 3031 E Alhambra Ave.\nLos Angeles,...        Commercial
# 413       Nestle Ave and Acre St\nLos Angeles, CA 91325             Other
# 451                             5110 District Boulevard        Industrial
# 452                             5102 District Boulevard        Industrial
# 453                                 4801 Slauson Avenue        Commercial
# ...                                                 ...               ...
# 2410                            624 N. San Gabriel Ave.        Commercial
# 2416                            624 N. San Gabriel Ave.        Commercial
# 2426                             1950 N. Central Avenue       Residential
# 2427                          500/600 E.  Compton Blvd.            Vacant
# 2428                              1716 Rosecrans Avenue            Vacant
#
#       NUM_OF_UNITS         SURPLUS_TYPE  PARCEL_SIZE  \
# 412            0.0  Exempt Surplus Land         0.00
# 413            0.0  Exempt Surplus Land         0.00
# 451            0.0         Surplus Land         0.27
# 452            0.0         Surplus Land         0.28
# 453            0.0         Surplus Land         0.35
# ...            ...                  ...          ...
# 2410           3.0               Excess         0.32
# 2416           3.0               Excess         0.32
# 2426          29.0         Surplus Land         3.00
# 2427         288.0         Surplus Land         2.37
# 2428          12.0         Surplus Land         0.30
#
#                                                   NOTES
# 412   Portion of sidewalk and lot in use by Auto Par...
# 413   Sliver of land next to private residence\n\nOP...
# 451              Existing 7,200 s.f. building is vacant
# 452              Existing 6,844 s.f. building is vacant
# 453              Existing 8,888 s.f. building is vacant
# ...                                                 ...
# 2410                   Will be declared exempt surplus.
# 2416                   Will be declared exempt surplus.
# 2426                                                NaN
# 2427  6166-022-900; 6166-022-902; 6166-222-903; 6166...
# 2428                                                NaN
#
# [124 rows x 10 columns]

# %%
counts = df.isna().sum()
print(counts.sort_values(ascending=False))
# Out:
# NOTES                47
# NUM_OF_UNITS         12
# JURISDICTION          0
# COUNTY                0
# YEAR                  0
# APN                   0
# STREET_ADDRESS        0
# EXISTING_USE_TYPE     0
# SURPLUS_TYPE          0
# PARCEL_SIZE           0
# dtype: int64

# %%
df.drop(columns=['NOTES'], inplace=True)

# %%
uniquy = df.nunique()
print(uniquy.sort_values(ascending=True))
# Out:
# COUNTY                 1
# YEAR                   2
# SURPLUS_TYPE           3
# EXISTING_USE_TYPE      6
# NUM_OF_UNITS           6
# JURISDICTION          16
# PARCEL_SIZE           61
# STREET_ADDRESS        93
# APN                  102
# dtype: int64

# %%
df.to_csv('G_clean.csv', index=False)
